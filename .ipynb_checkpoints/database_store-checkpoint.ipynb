# %%
import pandas as pd 

tweetData = pd.read_csv('cleaned_data.csv')

tweetData.head()
# Out:
#      Datetime    username                                             tweets
# 0  2021-06-07    FlyFM958  if you put a frog in the water and slowly rais...
# 1  2021-06-07      shrrr4  sebok psl kerajaan gagal but they be still cro...
# 2  2021-06-07  MinElly287    insyaallah we can do this stay at home please
# 3  2021-06-07    dinoyong  a bit of relief seeing this downtrend pray har...
# 4  2021-06-07   miyanlov3                   stay home ja  tak payah merayau

# %%
import mysql.connector as msql
from mysql.connector import Error

try:
    conn = msql.connect(host='localhost', user='root', 
                        password='aDilahmAsukaIr123')
    
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE covidEmotionDB")
        print("covidEmotionDB database is created")
        
except Error as e:
    print("Error while connecting to MYSQL", e)
# Out:
# Error while connecting to MYSQL 1007 (HY000): Can't create database 'covidemotiondb'; database exists

# %%
tweetData.dtypes
# Out:
# Datetime    object
# username    object
# tweets      object
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost', database='covidEmotionDB', 
                        user='root', password='aDilahmAsukaIr123')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS covidTweets')
        print('Creating table...')
        cursor.execute("CREATE TABLE covidTweets (datetime CHAR(100) NOT NULL, username CHAR(100) NOT NULL, tweets VARCHAR(300) NOT NULL)")
        print("covidTweets table is created...")
        
        for i,row in tweetData.iterrows():
            sql = "INSERT INTO covidemotiondb.covidTweets VALUES (%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            conn.commit()
            
except Error as e:
    print("Error while connecting to MYSQL", e)
# Out:
# You're connected to database:  ('covidemotiondb',)
# Creating table...
# covidTweets table is created...
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
#execute query
sql = "SELECT * FROM covidtweets"
cursor.execute(sql)

#fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (datetime.date(2021, 6, 7), 'FlyFM958', 'if you put a frog in the water and slowly raise the temperature it will stay until it is boiled to death ')
# (datetime.date(2021, 6, 7), 'shrrr4', 'sebok psl kerajaan gagal but they be still crossing district jumpa gf bf org mcm ni smpai mampos la tak habis pkp stay at home laaa susah ke mati ke tk jumpa bf gf korng tu haih')
# (datetime.date(2021, 6, 7), 'MinElly287', 'insyaallah we can do this stay at home please  ')
# (datetime.date(2021, 6, 7), 'dinoyong', 'a bit of relief seeing this downtrend pray hard and continue stay home')
# (datetime.date(2021, 6, 7), 'miyanlov3', 'stay home ja  tak payah merayau ')
# (datetime.date(2021, 6, 7), 'RajaAmieraa', 'saya ni dah stay home tau tapi kes still juga naik ')
# (datetime.date(2021, 6, 7), 'Syuk_RCs', 'walaupun ada turun   please stay home lagi jgn nk kuar tak tentu pasaiii   ')
# ...
